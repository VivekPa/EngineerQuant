# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set()

# %%
treasury_yields = pd.read_csv('treasury_yield_2019_2020.csv', index_col=0)
treasury_yields.head()
# Out:
#             1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 01/02/2019  2.40  2.40  2.42  2.51  2.60  2.50  2.47  2.49  2.56   2.66
# 01/03/2019  2.42  2.42  2.41  2.47  2.50  2.39  2.35  2.37  2.44   2.56
# 01/04/2019  2.40  2.42  2.42  2.51  2.57  2.50  2.47  2.49  2.56   2.67
# 01/07/2019  2.42  2.42  2.45  2.54  2.58  2.53  2.51  2.53  2.60   2.70
# 01/08/2019  2.40  2.42  2.46  2.54  2.60  2.58  2.57  2.58  2.63   2.73
#
#             20 Yr  30 Yr
# Date
# 01/02/2019   2.83   2.97
# 01/03/2019   2.75   2.92
# 01/04/2019   2.83   2.98
# 01/07/2019   2.86   2.99
# 01/08/2019   2.88   3.00

# %%
treasury_yields.index = pd.to_datetime(treasury_yields.index)
type(treasury_yields.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
treasury_yields.head()
# Out:
#             1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2019-01-02  2.40  2.40  2.42  2.51  2.60  2.50  2.47  2.49  2.56   2.66
# 2019-01-03  2.42  2.42  2.41  2.47  2.50  2.39  2.35  2.37  2.44   2.56
# 2019-01-04  2.40  2.42  2.42  2.51  2.57  2.50  2.47  2.49  2.56   2.67
# 2019-01-07  2.42  2.42  2.45  2.54  2.58  2.53  2.51  2.53  2.60   2.70
# 2019-01-08  2.40  2.42  2.46  2.54  2.60  2.58  2.57  2.58  2.63   2.73
#
#             20 Yr  30 Yr
# Date
# 2019-01-02   2.83   2.97
# 2019-01-03   2.75   2.92
# 2019-01-04   2.83   2.98
# 2019-01-07   2.86   2.99
# 2019-01-08   2.88   3.00

# %%
maturity = [1/12, 2/12, 3/12, 6/12, 1, 2, 3, 5, 7, 10, 20, 30]

# %%
plt.scatter(maturity, treasury_yields.loc['2020-01-02'])
plt.scatter(maturity, treasury_yields.loc['2020-12-01'])
